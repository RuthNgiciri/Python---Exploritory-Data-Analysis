# %%
#Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_2018 = pd.read_csv("C:/Users/RUTH LILLY/Downloads/archive/IT_Salary_Survey_EU_2018.csv")
df_2019 = pd.read_csv("C:/Users/RUTH LILLY/Downloads/archive/IT_Salary_Survey_EU_2019.csv")
df_2020 = pd.read_csv("C:/Users/RUTH LILLY/Downloads/archive/IT_Salary_Survey_EU_2020.csv")

df_2018
df_2019
df_2020
# Out:
#                 Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 0                          Software Engineer                         5
# 1                          Backend Developer                         7
# 2                          Software Engineer                        12
# ...

# %%
combined_df = pd.concat([df_2018, df_2019, df_2020])
combined_df
# Out:
#                 Timestamp   Age Gender         City  \
# 0     14/12/2018 12:41:33  43.0      M      München
# 1     14/12/2018 12:42:09  33.0      F      München
# 2     14/12/2018 12:47:36  32.0      M      München
# 3     14/12/2018 12:50:15  25.0      M      München
# 4     14/12/2018 12:50:31  39.0      M      München
# ...                   ...   ...    ...          ...
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                            Position  Years of experience Your level  \
# 0                      QA Ingenieur                 11.0     Senior
# 1     Senior PHP Magento developer                   8.0     Senior
# 2                 Software Engineer                 10.0     Senior
# ...

# %%
# Print the first 5 rows of the data
print(combined_df.head())
# Out:
#              Timestamp   Age Gender     City                       Position  \
# 0  14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1  14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2  14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3  14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4  14/12/2018 12:50:31  39.0      M  München                    UX Designer
#
#    Years of experience Your level  Current Salary  Salary one year ago  \
# 0                 11.0     Senior         77000.0              76200.0
# 1                  8.0     Senior         65000.0              55000.0
# 2                 10.0     Senior         88000.0              73000.0
# 3                  6.0     Senior         78000.0              55000.0
# 4                 10.0     Senior         69000.0              60000.0
#
#    Salary two years ago  ... Years of experience in Germany  \
# ...

# %%
# Print the shape of the data (number of rows, number of columns)
print(combined_df.shape)
print(df_2018.shape)
print(df_2019.shape)
print(df_2020.shape)
# Out:
# (3009, 42)
# (765, 14)
# (991, 23)
# (1253, 23)

# %%
# Print some basic information about the data (data types, missing values)
print(combined_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3009 entries, 0 to 1252
# Data columns (total 42 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                2018 non-null   object
#  1   Age                                                                                                                      2780 non-null   float64
#  2   Gender                                                                                                                   2985 non-null   object
# ...

# %%
print(df_2018.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 765 entries, 0 to 764
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Timestamp                           765 non-null    object
#  1   Age                                 672 non-null    float64
#  2   Gender                              751 non-null    object
#  3   City                                736 non-null    object
#  4   Position                            737 non-null    object
#  5   Years of experience                 732 non-null    float64
#  6   Your level                          743 non-null    object
#  7   Current Salary                      750 non-null    float64
#  8   Salary one year ago                 596 non-null    float64
#  9   Salary two years ago                463 non-null    float64
#  10  Are you getting any Stock Options?  742 non-null    object
# ...

# %%
# Print some basic descriptive statistics about the data
print(df_2018.describe())
# Out:
#               Age  Years of experience  Current Salary  Salary one year ago  \
# count  672.000000           732.000000      750.000000           596.000000
# mean    32.183036             8.548497    68381.765333         62187.278523
# std      5.107268             4.729557    21196.306557         20163.008663
# min     21.000000             0.000000    10300.000000         10001.000000
# 25%     29.000000             5.000000    57000.000000         52000.000000
# 50%     32.000000             8.000000    65000.000000         60000.000000
# 75%     35.000000            11.000000    75000.000000         70000.000000
# max     60.000000            38.000000   200000.000000        200000.000000
#
#        Salary two years ago
# count            463.000000
# mean           58013.475162
# std            20413.048908
# min            10001.000000
# 25%            48000.000000
# 50%            56000.000000
# 75%            67000.000000
# max           150000.000000

# %%
#Create a histogram for the Salary Column
plt.hist(df_2018["Current Salary"], bins=1000)
plt.xlabel("Current Salary")
plt.ylabel("Count")
plt.show()

# %%
# Create a scatterplot of Age vs. Salary
plt.scatter(df_2018["Age"], df["Current Salary"])
plt.xlabel("Age")
plt.ylabel("Current Salary")
plt.show()

# %%
# Create a boxplot of Salary by Gender
sns.boxplot(x="Gender", y="Current Salary", data=df_2018)
plt.show()
